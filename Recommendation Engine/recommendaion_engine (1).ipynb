# %% [markdown]
# # Dataset Schema
#
# ## 1. User Data (user_data.csv)
#
# | Column Name   | Data Type | Description                                           |
# |---------------|-----------|-------------------------------------------------------|
# | UserID        | string    | Unique identifier for the user.                      |
# | FirstName     | string    | First name of the user.                              |
# | LastName      | string    | Last name of the user.                               |
# | Email         | string    | Email address of the user.                           |
# | Gender        | string    | Gender of the user (e.g., Male, Female, Other).     |
# | AgeGroup      | string    | Age group of the user (e.g., 18-25, 26-35).         |
# | City          | string    | City of residence.                                   |
# | Country       | string    | Country of residence.                                |
# | DateOfBirth   | date      | Date of birth in YYYY-MM-DD format.                 |
#
# ---
#
# ## 2. Product Data (product_data.csv)
#
# | Column Name     | Data Type | Description                                           |
# |-----------------|-----------|-------------------------------------------------------|
# | ProductID       | string    | Unique identifier for the product.                   |
# | ProductName     | string    | Name of the product.                                 |
# | Category        | string    | Product category (e.g., Electronics, Clothing).      |
# | BasePrice       | float     | Base price of the product.                           |
# | DiscountAmount   | float     | Discount on the product.                             |
# | StockQuantity   | int       | Available stock quantity.                            |
# | Description     | string    | Short description of the product.                    |
#
# ---
#
# ## 3. Transaction Data (transaction_data.csv)
#
# | Column Name         | Data Type | Description                                           |
# |---------------------|-----------|-------------------------------------------------------|
# | TransactionID       | string    | Unique identifier for the transaction.               |
# | UserID              | string    | Unique identifier for the user making the transaction.|
# | ProductID           | string    | Unique identifier for the purchased product.         |
# | TransactionAmount    | float     | Total transaction amount.                             |
# | PaymentMethod       | string    | Payment method used (e.g., Credit Card, PayPal).    |
# | PurchaseDate        | date      | Date of the transaction in YYYY-MM-DD format.       |
# | DeliveryTime        | int       | Delivery time in days.                               |
# | DiscountAmount      | float     | Discount applied during the transaction.             |
#
# ---
#
# ## 4. Interaction Data (interaction_data.csv)
#
# | Column Name             | Data Type | Description                                           |
# |-------------------------|-----------|-------------------------------------------------------|
# | InteractionID           | string    | Unique identifier for the interaction.               |
# | UserID                  | string    | Unique identifier for the interacting user.          |
# | ProductID               | string    | Unique identifier for the interacted product.        |
# | ViewedPages             | int       | Number of product pages viewed.                       |
# | ProductViewHistory      | int       | Number of times the product was viewed historically.  |
# | SearchQueries           | int       | Number of search queries related to the product.      |
# | TimeSpentOnPages        | float     | Total time spent on product pages in minutes.        |
# | WishlistItems           | int       | Number of times the product was added to the wishlist.|
# | CartAddedItems          | int       | Number of times the product was added to the cart.    |
# | CartAbandonedItems      | int       | Number of times the product was abandoned in the cart.|
# | ReviewRating            | int       | Product rating given by the user (1-5), or null.     |
# | ReviewText              | string    | Review text given by the user, if any.               |

# %% [markdown]
# # Recommendation System Development Roadmap
#
# ## Phase 0: Project Preparation
# ### Milestone 0.1: Project Setup
# - [ ] Set up development environment
# - [ ] Configure version control (Git)
# - [ ] Install necessary libraries and frameworks
# - [ ] Create project structure and documentation
#
# ### Milestone 0.2: Data Acquisition
# - [ ] Collect and verify all datasets
#   - [ ] `user_data.csv`
#   - [ ] `product_data.csv`
#   - [ ] `interaction_data.csv`
#   - [ ] `transaction_data.csv`
# - [ ] Perform initial data inventory and validation
# - [ ] Set up secure data storage and access protocols
#
# ## Phase 1: Data Preprocessing
# ### Milestone 1.1: Data Cleaning
# - [ ] Develop data cleaning scripts
# - [ ] Handle missing values in all datasets
# - [ ] Normalize numerical features
# - [ ] Validate data integrity after cleaning
#
# ### Milestone 1.2: Data Merging and Linking
# - [ ] Implement data merging logic using `UserID` and `ProductID`
# - [ ] Create comprehensive merged dataset
# - [ ] Develop data validation checks for merged data
#
# ### Milestone 1.3: Feature Engineering
# - [ ] Extract derived features
#   - [ ] `EffectivePrice`
#   - [ ] `TotalSpentPerUser`
#   - [ ] `AverageRatingPerProduct`
# - [ ] Create user-product interaction matrices
# - [ ] Develop feature engineering pipeline
# - [ ] Validate and document new features
#
# ## Phase 2: Model Development
# ### Milestone 2.1: Collaborative Filtering Models
# - [ ] Implement User-Based Collaborative Filtering
# - [ ] Develop Item-Based Collaborative Filtering
# - [ ] Create evaluation framework for CF models
# - [ ] Perform initial model testing and validation
#
# ### Milestone 2.2: Content-Based Filtering
# - [ ] Develop product similarity computation
# - [ ] Implement content-based recommendation algorithm
# - [ ] Create feature extraction for product descriptions
# - [ ] Test and validate content-based recommendations
#
# ### Milestone 2.3: User Clustering and Matrix Factorization
# - [ ] Develop user clustering algorithms
# - [ ] Implement matrix factorization techniques
# - [ ] Create recommendation strategies based on clusters
# - [ ] Validate clustering and matrix factorization approaches
#
# ### Milestone 2.4: Hybrid Recommendation System
# - [ ] Develop weighted combination strategy
# - [ ] Implement ranking aggregation algorithms
# - [ ] Create meta-model for recommendation fusion
# - [ ] Perform comprehensive hybrid model testing
#
# ## Phase 3: Model Evaluation
# ### Milestone 3.1: Performance Metrics
# - [ ] Implement evaluation metrics
#   - [ ] Precision
#   - [ ] Recall
#   - [ ] F1-Score
#   - [ ] Mean Average Precision (MAP)
#   - [ ] Mean Reciprocal Rank (MRR)
# - [ ] Develop cross-validation framework
# - [ ] Create comprehensive reporting system
#
# ### Milestone 3.2: Model Comparison and Selection
# - [ ] Conduct comparative analysis of different models
# - [ ] Perform hyperparameter tuning
# - [ ] Select and finalize recommendation approach
# - [ ] Document model performance and rationale
#
# ## Phase 4: Deployment Preparation
# ### Milestone 4.1: Backend Development
# - [ ] Set up Flask/Django backend
# - [ ] Implement recommendation API endpoints
# - [ ] Develop data processing and model serving infrastructure
# - [ ] Create system for real-time recommendation updates
#
# ### Milestone 4.2: Frontend Integration
# - [ ] Design recommendation visualization components
# - [ ] Implement UI/UX for displaying recommendations
# - [ ] Develop user interaction tracking
# - [ ] Create feedback mechanism for recommendations
#
# ### Milestone 4.3: System Testing
# - [ ] Perform end-to-end system testing
# - [ ] Conduct performance and load testing
# - [ ] Implement monitoring and logging
# - [ ] Develop rollback and recovery procedures
#
# ## Phase 5: Continuous Improvement
# ### Milestone 5.1: Feedback Loop
# - [ ] Implement real-time recommendation refinement
# - [ ] Develop A/B testing framework
# - [ ] Create mechanism for explainable recommendations
# - [ ] Set up continuous model retraining pipeline
#
# ### Milestone 5.2: Advanced Features
# - [ ] Explore deep learning recommendation approaches
# - [ ] Develop more sophisticated personalization techniques
# - [ ] Investigate emerging recommendation technologies

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder, StandardScaler,LabelEncoder

# %% [markdown]
# ## User Data Preprocessing

# %%
user_data = pd.read_csv('user_data.csv')
user_data.head()
# Out:
#                                  UserID FirstName  LastName  \
# 0  0a257610-2c9f-4212-999b-8a68488d93fb   Kristin    Phelps
# 1  8fad3372-6d02-4263-929c-e94c822c6f10   Tiffany      Lowe
# 2  313c6b2f-bc3e-467b-ae1f-e29eb68ce6a5   Brandon   Escobar
# 3  40c587b7-4fe5-4fe2-b89a-3c0cd492de8c    Dalton  Espinoza
# 4  05a698a7-5a3d-432e-ac6f-f962ee54d163      Gary    Monroe
#
#                    Email  Gender AgeGroup          City           Country  \
# 0  anthony93@example.net   Other    18-25     Butlerton       Puerto Rico
# 1   robert39@example.com  Female    26-35  East Zachary  French Polynesia
# 2  melissa13@example.org    Male    46-60  North Teresa     Cote d'Ivoire
# 3  ywilliams@example.org   Other      60+     New Carly          Mongolia
# 4   alyssa31@example.net    Male      60+  Barbarashire           Uruguay
#
#   DateOfBirth
# 0  1947-03-30
# 1  1987-04-30
# 2  1956-04-29
# 3  1946-05-12
# 4  1955-11-01

# %%
user_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   UserID       30000 non-null  object
#  1   FirstName    30000 non-null  object
#  2   LastName     30000 non-null  object
#  3   Email        26989 non-null  object
#  4   Gender       30000 non-null  object
#  5   AgeGroup     30000 non-null  object
#  6   City         30000 non-null  object
#  7   Country      30000 non-null  object
#  8   DateOfBirth  30000 non-null  object
# dtypes: object(9)
# memory usage: 2.1+ MB

# %%
user_data.isnull().sum()
# Out:
# UserID            0
# FirstName         0
# LastName          0
# Email          3011
# Gender            0
# AgeGroup          0
# City              0
# Country           0
# DateOfBirth       0
# dtype: int64

# %%
user_data['Email'] = user_data['Email'].fillna('unknown@example.com')

# %%
user_data.head()
# Out:
#                                  UserID FirstName  LastName  \
# 0  0a257610-2c9f-4212-999b-8a68488d93fb   Kristin    Phelps
# 1  8fad3372-6d02-4263-929c-e94c822c6f10   Tiffany      Lowe
# 2  313c6b2f-bc3e-467b-ae1f-e29eb68ce6a5   Brandon   Escobar
# 3  40c587b7-4fe5-4fe2-b89a-3c0cd492de8c    Dalton  Espinoza
# 4  05a698a7-5a3d-432e-ac6f-f962ee54d163      Gary    Monroe
#
#                    Email  Gender AgeGroup          City           Country  \
# 0  anthony93@example.net   Other    18-25     Butlerton       Puerto Rico
# 1   robert39@example.com  Female    26-35  East Zachary  French Polynesia
# 2  melissa13@example.org    Male    46-60  North Teresa     Cote d'Ivoire
# 3  ywilliams@example.org   Other      60+     New Carly          Mongolia
# 4   alyssa31@example.net    Male      60+  Barbarashire           Uruguay
#
#   DateOfBirth
# 0  1947-03-30
# 1  1987-04-30
# 2  1956-04-29
# 3  1946-05-12
# 4  1955-11-01

# %% [markdown]
# ## Product data preprocessing

# %%
product_data  = pd.read_csv('product_data.csv')

# %%
product_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ProductID       350 non-null    object
#  1   ProductName     350 non-null    object
#  2   Category        350 non-null    object
#  3   BasePrice       330 non-null    float64
#  4   DiscountAmount  330 non-null    float64
#  5   StockQuantity   350 non-null    int64
#  6   Description     350 non-null    object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 19.3+ KB

# %%
product_data.isnull().sum()
# Out:
# ProductID          0
# ProductName        0
# Category           0
# BasePrice         20
# DiscountAmount    20
# StockQuantity      0
# Description        0
# dtype: int64

# %%
# Replace NaN values in BasePrice with the mean of the column
product_data['BasePrice'] = product_data['BasePrice'].fillna(product_data['BasePrice'].mean())

# Replace NaN values in DiscountAmount with the mean of the column
product_data['DiscountAmount'] = product_data['DiscountAmount'].fillna(product_data['DiscountAmount'].mean())

# %%
product_data.head()
# Out:
#                               ProductID  \
# 0  1a6b586e-653b-4d7e-bed5-ff548bfdcb6f
# 1  e6221569-571e-4ed5-914c-aa70b3f54cb8
# 2  cb898d87-eaf9-4604-966e-a5ec8d2c21f6
# 3  800cbbdd-1af3-4cb6-b082-8b5176873768
# 4  eee6d8cd-8a78-4db8-b3d4-5085592a0147
#
#                              ProductName        Category   BasePrice  \
# 0              Seamless maximized access  Home & Kitchen  254.940000
# 1   Streamlined client-server capability        Clothing  886.588473
# 2  Managed zero tolerance conglomeration           Books  223.560000
# 3           Innovative logistical portal            Toys  975.550000
# 4        Decentralized coherent firmware            Toys  840.510000
#
#    DiscountAmount  StockQuantity  \
# 0          46.440            822
# 1         144.165            904
# 2          22.190            479
# 3          73.970            589
# 4         232.330            592
#
#                                          Description
# 0  Everyone place air reason low well bag service...
# 1  Our again at reduce citizen quality must bar e...
# 2  Last may feel tend door conference simply diff...
# 3  Technology not near that no garden table magaz...
# 4  Watch sure discussion you commercial job wide ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
plt.boxplot(product_data['BasePrice'], vert=False)
plt.title('Boxplot of BasePrice')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.boxplot(product_data['DiscountAmount'], vert=False)
plt.title('Boxplot of DiscountAmount')
plt.show()

# %%
# Remove outliers in BasePrice and DiscountAmount using the Z-score method
from scipy import stats

# Function to remove outliers based on Z-score
def remove_outliers(df, column):
    z_scores = np.abs(stats.zscore(df[column]))
    return df[(z_scores < 3)]

# Apply the function to BasePrice and DiscountAmount
product_data = remove_outliers(product_data, 'BasePrice')
product_data = remove_outliers(product_data, 'DiscountAmount')

# %% [markdown]
# ## Transactional data Preprocessing

# %%
transaction_data  = pd.read_csv('transaction_data.csv')

# %%
transaction_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   TransactionID      30000 non-null  object
#  1   UserID             30000 non-null  object
#  2   ProductID          30000 non-null  object
#  3   TransactionAmount  27057 non-null  float64
#  4   PaymentMethod      30000 non-null  object
#  5   PurchaseDate       30000 non-null  object
#  6   DeliveryTime       30000 non-null  int64
#  7   DiscountAmount     27057 non-null  float64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 1.8+ MB

# %%
transaction_data.isnull().sum()
# Out:
# TransactionID           0
# UserID                  0
# ProductID               0
# TransactionAmount    2943
# PaymentMethod           0
# PurchaseDate            0
# DeliveryTime            0
# DiscountAmount       2943
# dtype: int64

# %%
import seaborn as sns
sns.displot(transaction_data['TransactionAmount'], kde=True)

# %%
# Replace NaN values in BasePrice with the mean of the column
transaction_data['TransactionAmount'] = transaction_data['TransactionAmount'].fillna(transaction_data['TransactionAmount'].median())

# Replace NaN values in DiscountAmount with the mean of the column
transaction_data['DiscountAmount'] = transaction_data['DiscountAmount'].fillna(transaction_data['DiscountAmount'].mean())

# %%
transaction_data.head()
# Out:
#                           TransactionID                                UserID  \
# 0  064170d5-341e-4042-adbc-a25403bc9915  7678999a-d7a6-40bf-ac1d-68ba4d95fe3d
# 1  68cc6b05-0b09-4483-9ccc-2f0da558ad58  4e58efd4-67b9-43a8-8121-f892ef84b27e
# 2  ad058982-0b59-401d-b4e6-e6b44a83e39d  04c1c832-ddf8-45ee-bfbc-fbcbc9378542
# 3  83371819-0358-4d86-960f-738c9c2a90d4  b37568d7-b9f0-4981-9619-126c231ecad8
# 4  77e6e26f-f92d-487a-956c-6540a2c77a61  78c8337f-5ec0-4e5a-ae52-121ee8c370bd
#
#                               ProductID  TransactionAmount     PaymentMethod  \
# 0  165a07ba-84af-45a2-8bb1-c7654334f4ff             768.58            PayPal
# 1  03f85424-d3ca-4bc5-8e67-2e0a9617676b             154.72        Debit Card
# 2  7843a4ce-d40e-42f2-b42d-e6d003e7da9d             753.88        Debit Card
# 3  de60a078-8d0f-4a74-b45d-75d4f41e872b             998.53            PayPal
# 4  ec3068f6-db84-4282-928a-cdcd07c05810             556.35  Cash on Delivery
#
#   PurchaseDate  DeliveryTime  DiscountAmount
# 0   2023-02-02            11      375.560000
# 1   2024-05-30             5       34.370000
# 2   2023-09-01            11        4.110000
# 3   2023-02-22             2      460.140000
# 4   2024-07-22            11      210.084149

# %%
# Create a boxplot to visualize outliers in TransactionAmount
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
plt.boxplot(transaction_data['TransactionAmount'])
plt.title('Boxplot of TransactionAmount')
plt.show()

# Create a boxplot to visualize outliers in DiscountAmount
plt.figure(figsize=(10,6))
plt.boxplot(transaction_data['DiscountAmount'])
plt.title('Boxplot of DiscountAmount')
plt.show()

# %%
# Remove outliers from TransactionAmount
transaction_data = remove_outliers(transaction_data, 'TransactionAmount')

# Remove outliers from DiscountAmount
transaction_data = remove_outliers(transaction_data, 'DiscountAmount')

# %% [markdown]
# ## Interaction Data Preprocessing

# %%
interaction_Data = pd.read_csv('interaction_data.csv')

# %%
interaction_Data.head()
# Out:
#                           InteractionID                                UserID  \
# 0  5985f0f0-f9a4-40ef-87f0-e3b3a7dffe82  72b742ce-3ce7-43c2-b58a-551199f95be4
# 1  24780e21-7064-4aac-8e98-0313ea1b0125  f6f48340-2cdd-4cb9-a057-f8a1615ed31c
# 2  03e9ec62-c42a-4ed6-b160-95b12de5cdb7  2e09bd9a-4a07-486e-906d-ec7d88528792
# 3  1080c35f-970e-4cc0-8a03-c9f2d906ff40  3ff99676-b021-4c6c-94cf-22d6d5668fad
# 4  890b219c-8ff7-4dc0-bf82-ad23e9a516f6  d5abe419-d24d-40e1-93dc-a086b327691d
#
#                               ProductID  ViewedPages  ProductViewHistory  \
# 0  16ef3477-7f44-4d68-ad1e-7c92115a454c           10                  16
# 1  2092caae-e5b8-41eb-b176-95d84b18fda0            9                  83
# 2  df762f01-6f9f-4b10-a13b-f92e007613e9            7                 100
# 3  07fc1417-cb66-4d36-bbb9-d80ba06b5833           14                  75
# 4  6d3f920f-9b89-417c-9ee5-545a0195c2cb           18                  11
#
#    SearchQueries  TimeSpentOnPages  WishlistItems  CartAddedItems  \
# 0              5               NaN              3               7
# 1              5               NaN              5               1
# 2             19             53.46              8              10
# 3              3             97.77              6               3
# 4              4             24.69              3               0
#
#    CartAbandonedItems  ReviewRating  \
# 0                   7           5.0
# 1                   3           2.0
# 2                  10           NaN
# 3                   2           4.0
# 4                  10           3.0
#
#                                           ReviewText
# 0          Cover recently last note case what space.
# 1  While safe environmental over read religious w...
# 2  Suffer Republican bed plan into nice have proj...
# 3  Religious explain high mind answer to push dev...
# 4                                                NaN

# %%
interaction_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   InteractionID       30000 non-null  object
#  1   UserID              30000 non-null  object
#  2   ProductID           30000 non-null  object
#  3   ViewedPages         30000 non-null  int64
#  4   ProductViewHistory  30000 non-null  int64
#  5   SearchQueries       30000 non-null  int64
#  6   TimeSpentOnPages    27074 non-null  float64
#  7   WishlistItems       30000 non-null  int64
#  8   CartAddedItems      30000 non-null  int64
#  9   CartAbandonedItems  30000 non-null  int64
#  10  ReviewRating        24094 non-null  float64
#  11  ReviewText          23931 non-null  object
# dtypes: float64(2), int64(6), object(4)
# memory usage: 2.7+ MB

# %%
interaction_Data.isnull().sum()
# Out:
# InteractionID            0
# UserID                   0
# ProductID                0
# ViewedPages              0
# ProductViewHistory       0
# SearchQueries            0
# TimeSpentOnPages      2926
# WishlistItems            0
# CartAddedItems           0
# CartAbandonedItems       0
# ReviewRating          5906
# ReviewText            6069
# dtype: int64

# %%
sns.displot(interaction_Data['TimeSpentOnPages'], kde=True)

# %%
sns.displot(interaction_Data['ReviewRating'], kde=True)

# %%
# Replace NaN values in TimeSpentOnPages with the median of the column
interaction_Data['TimeSpentOnPages'] = interaction_Data['TimeSpentOnPages'].fillna(interaction_Data['TimeSpentOnPages'].median())

# Replace NaN values in ReviewRating with the mean of the column
interaction_Data['ReviewRating'] = interaction_Data['ReviewRating'].fillna(interaction_Data['ReviewRating'].mean())

# %%
interaction_Data['ReviewText'] = interaction_Data['ReviewText'].fillna('No review provided')

# %%
# Function to visualize outliers in specified columns
def visualize_outliers(df, columns):
    num_columns = len(columns)
    num_rows = (num_columns + 1) // 2  # Calculate number of rows needed
    plt.figure(figsize=(15, num_rows * 5))  # Adjust figure size based on number of rows
    for i, column in enumerate(columns, 1):
        plt.subplot(num_rows, 2, i)  # Create subplots in a grid
        plt.boxplot(df[column])
        plt.title(f'Boxplot of {column}')
        plt.xlabel(column)
    plt.tight_layout()
    plt.show()

# Visualize outliers in relevant columns of interaction_Data
visualize_outliers(interaction_Data, ['TimeSpentOnPages', 'ViewedPages', 'SearchQueries', 
                                       'WishlistItems', 'CartAddedItems', 
                                       'CartAbandonedItems', 'ReviewRating'])

# %%
from scipy import stats

# Function to remove outliers based on Z-score
def remove_outliers(df, column):
    z_scores = np.abs(stats.zscore(df[column]))
    return df[(z_scores < 3)]

# Apply the function to relevant columns in interaction_Data
interaction_Data = remove_outliers(interaction_Data, 'TimeSpentOnPages')

# %% [markdown]
# ## Normalize Numerical Features

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# Product Data
product_data['BasePrice'] = scaler.fit_transform(product_data[['BasePrice']])
product_data['DiscountAmount'] = scaler.fit_transform(product_data[['DiscountAmount']])
product_data['StockQuantity'] = scaler.fit_transform(product_data[['StockQuantity']])

# Interaction Data
interaction_Data[['ViewedPages', 'TimeSpentOnPages']] = scaler.fit_transform(
    interaction_Data[['ViewedPages', 'TimeSpentOnPages']]
)

# Transaction Data
transaction_data['TransactionAmount'] = scaler.fit_transform(transaction_data[['TransactionAmount']])

# %% [markdown]
# ## Encode Categorical Features

# %%
# User Data
label_encoder = LabelEncoder()
user_data['Gender'] = label_encoder.fit_transform(user_data['Gender'])
user_data['AgeGroup'] = label_encoder.fit_transform(user_data['AgeGroup'])
user_data['City'] = label_encoder.fit_transform(user_data['City'])
user_data['Country'] = label_encoder.fit_transform(user_data['Country'])

# Product Data
product_data['Category'] = label_encoder.fit_transform(product_data['Category'])

# Transaction Data
transaction_data['PaymentMethod'] = label_encoder.fit_transform(transaction_data['PaymentMethod'])

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### User Features

# %%
# Age from DateOfBirth
user_data['Age'] = pd.to_datetime("today").year - pd.to_datetime(user_data['DateOfBirth']).dt.year

# Total transactions and spending per user
user_transactions = transaction_data.groupby('UserID').agg(
    TotalSpent=('TransactionAmount', 'sum'),
    TotalTransactions=('TransactionID', 'count')
).reset_index()

# Merge with user_data
user_data = user_data.merge(user_transactions, on='UserID', how='left')
user_data.fillna(0, inplace=True)  # Fill missing totals with 0

# %% [markdown]
# ### Product Features

# %%
# Effective Price
product_data['EffectivePrice'] = product_data['BasePrice'] - product_data['DiscountAmount']

# Average Rating Per Product
product_ratings = interaction_Data.groupby('ProductID')['ReviewRating'].mean().reset_index()
product_ratings.rename(columns={'ReviewRating': 'AverageRating'}, inplace=True)

# Merge with product_data
product_data = product_data.merge(product_ratings, on='ProductID', how='left')
product_data['AverageRating'].fillna(0, inplace=True)
# Out:
# C:\Users\Ojshav\AppData\Local\Temp\ipykernel_15876\3176615890.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   product_data['AverageRating'].fillna(0, inplace=True)

# %% [markdown]
# ### User-Product Interaction Features

# %%
# Total interactions per user
user_interactions = interaction_Data.groupby('UserID').agg(
    TotalViews=('ViewedPages', 'sum'),
    TotalTimeSpent=('TimeSpentOnPages', 'sum'),
    WishlistCount=('WishlistItems', 'sum')
).reset_index()

# Merge with user_data
user_data = user_data.merge(user_interactions, on='UserID', how='left')
user_data.fillna(0, inplace=True)

# %%
user_data.head()
# Out:
#                                  UserID FirstName  LastName  \
# 0  0a257610-2c9f-4212-999b-8a68488d93fb   Kristin    Phelps
# 1  8fad3372-6d02-4263-929c-e94c822c6f10   Tiffany      Lowe
# 2  313c6b2f-bc3e-467b-ae1f-e29eb68ce6a5   Brandon   Escobar
# 3  40c587b7-4fe5-4fe2-b89a-3c0cd492de8c    Dalton  Espinoza
# 4  05a698a7-5a3d-432e-ac6f-f962ee54d163      Gary    Monroe
#
#                    Email  Gender  AgeGroup   City  Country DateOfBirth  Age  \
# 0  anthony93@example.net       2         0   1147      175  1947-03-30   77
# 1   robert39@example.com       0         1   3642       74  1987-04-30   37
# 2  melissa13@example.org       1         3  11101       52  1956-04-29   68
# 3  ywilliams@example.org       2         4   8689      142  1946-05-12   78
# 4   alyssa31@example.net       1         4    585      233  1955-11-01   69
#
#    TotalSpent  TotalTransactions  TotalViews  TotalTimeSpent  WishlistCount
# 0    0.170386                1.0    0.000000        0.000000            0.0
# 1    0.511270                4.0    1.000000        0.073209            9.0
# 2    0.375898                1.0    0.315789        0.099326            8.0
# 3    0.200442                1.0    0.000000        0.000000            0.0
# 4    0.000000                0.0    0.000000        0.000000            0.0

# %% [markdown]
# ## Collaborative Filtering on Interaction Data
# 1.1 Import Required Libraries

# %%
from sklearn.metrics.pairwise import cosine_similarity
import scipy.sparse as sp

# %%
interaction_Data.head()
# Out:
#                           InteractionID                                UserID  \
# 0  5985f0f0-f9a4-40ef-87f0-e3b3a7dffe82  72b742ce-3ce7-43c2-b58a-551199f95be4
# 1  24780e21-7064-4aac-8e98-0313ea1b0125  f6f48340-2cdd-4cb9-a057-f8a1615ed31c
# 2  03e9ec62-c42a-4ed6-b160-95b12de5cdb7  2e09bd9a-4a07-486e-906d-ec7d88528792
# 3  1080c35f-970e-4cc0-8a03-c9f2d906ff40  3ff99676-b021-4c6c-94cf-22d6d5668fad
# 4  890b219c-8ff7-4dc0-bf82-ad23e9a516f6  d5abe419-d24d-40e1-93dc-a086b327691d
#
#                               ProductID  ViewedPages  ProductViewHistory  \
# 0  16ef3477-7f44-4d68-ad1e-7c92115a454c     0.473684                  16
# 1  2092caae-e5b8-41eb-b176-95d84b18fda0     0.421053                  83
# 2  df762f01-6f9f-4b10-a13b-f92e007613e9     0.315789                 100
# 3  07fc1417-cb66-4d36-bbb9-d80ba06b5833     0.684211                  75
# 4  6d3f920f-9b89-417c-9ee5-545a0195c2cb     0.894737                  11
#
#    SearchQueries  TimeSpentOnPages  WishlistItems  CartAddedItems  \
# 0              5          0.123786              3               7
# 1              5          0.123786              5               1
# 2             19          0.099916              8              10
# 3              3          0.184326              6               3
# 4              4          0.045110              3               0
#
#    CartAbandonedItems  ReviewRating  \
# 0                   7      5.000000
# 1                   3      2.000000
# 2                  10      3.006931
# 3                   2      4.000000
# 4                  10      3.000000
#
#                                           ReviewText
# 0          Cover recently last note case what space.
# 1  While safe environmental over read religious w...
# 2  Suffer Republican bed plan into nice have proj...
# 3  Religious explain high mind answer to push dev...
# 4                                 No review provided

# %%
# Sample weights for the features
weights = {
    'ViewedPages': 1,
    'ProductViewHistory': 2,
    'SearchQueries': 3,
    'TimeSpentOnPages': 2,
    'WishlistItems': 4,
    'CartAddedItems': 5,
    'CartAbandonedItems': -2,
    'ReviewRating': 3
}

# Function to compute composite score
def calculate_composite_score(row):
    score = 0
    for feature, weight in weights.items():
        score += row[feature] * weight
    return score

# %% [markdown]
# 1.2 Prepare Interaction Matrix

# %%
# Add a composite score to the interaction data
interaction_Data['CompositeScore'] = interaction_Data.apply(calculate_composite_score, axis=1)

# Create the interaction matrix: Users x Products with composite scores
interaction_matrix = interaction_Data.pivot_table(
    index='UserID', columns='ProductID', values='CompositeScore', fill_value=0
)

# %%
interaction_matrix.head()
# Out:
# ProductID                             019313e2-671d-464e-8103-b25906b3467e  \
# UserID
# 0008ed95-9c61-4158-8e52-42cd0ca8d91a                                   0.0
# 00138209-0337-4d01-939a-8f96ec0a3e01                                   0.0
# 001391f8-8ccf-4ab5-ad79-2fdc6f47d715                                   0.0
# 0013b292-8412-4fef-b569-bfa2309c930c                                   0.0
# 001a2502-a12e-4f49-9bfe-5f26df6b7458                                   0.0
#
# ProductID                             026371c3-35b4-470a-899a-64baf6d6e1c3  \
# UserID
# 0008ed95-9c61-4158-8e52-42cd0ca8d91a                                   0.0
# 00138209-0337-4d01-939a-8f96ec0a3e01                                   0.0
# 001391f8-8ccf-4ab5-ad79-2fdc6f47d715                                   0.0
# 0013b292-8412-4fef-b569-bfa2309c930c                                   0.0
# 001a2502-a12e-4f49-9bfe-5f26df6b7458                                   0.0
#
# ProductID                             03b63f38-63bd-4946-89bd-a14b2e2efa7f  \
# UserID
# 0008ed95-9c61-4158-8e52-42cd0ca8d91a                                   0.0
# 00138209-0337-4d01-939a-8f96ec0a3e01                                   0.0
# 001391f8-8ccf-4ab5-ad79-2fdc6f47d715                                   0.0
# 0013b292-8412-4fef-b569-bfa2309c930c                                   0.0
# 001a2502-a12e-4f49-9bfe-5f26df6b7458                                   0.0
#
# ProductID                             03f85424-d3ca-4bc5-8e67-2e0a9617676b  \
# UserID
# 0008ed95-9c61-4158-8e52-42cd0ca8d91a                                   0.0
# 00138209-0337-4d01-939a-8f96ec0a3e01                                   0.0
# 001391f8-8ccf-4ab5-ad79-2fdc6f47d715                                   0.0
# 0013b292-8412-4fef-b569-bfa2309c930c                                   0.0
# 001a2502-a12e-4f49-9bfe-5f26df6b7458                                   0.0
#
# ProductID                             04187810-a586-455a-9eaf-13bae2f9431c  \
# UserID
# 0008ed95-9c61-4158-8e52-42cd0ca8d91a                                   0.0
# 00138209-0337-4d01-939a-8f96ec0a3e01                                   0.0
# 001391f8-8ccf-4ab5-ad79-2fdc6f47d715                                   0.0
# 0013b292-8412-4fef-b569-bfa2309c930c                                   0.0
# 001a2502-a12e-4f49-9bfe-5f26df6b7458                                   0.0
#
# ProductID                             0426041e-ed9b-48da-9db6-ed4fa574056d  \
# UserID
# 0008ed95-9c61-4158-8e52-42cd0ca8d91a                                   0.0
# 00138209-0337-4d01-939a-8f96ec0a3e01                                   0.0
# 001391f8-8ccf-4ab5-ad79-2fdc6f47d715                                   0.0
# 0013b292-8412-4fef-b569-bfa2309c930c                                   0.0
# 001a2502-a12e-4f49-9bfe-5f26df6b7458                                   0.0
#
# ProductID                             04963a3a-56f9-406f-8e71-969ad9fd4b89  \
# UserID
# 0008ed95-9c61-4158-8e52-42cd0ca8d91a                                   0.0
# 00138209-0337-4d01-939a-8f96ec0a3e01                                   0.0
# 001391f8-8ccf-4ab5-ad79-2fdc6f47d715                                   0.0
# 0013b292-8412-4fef-b569-bfa2309c930c                                   0.0
# 001a2502-a12e-4f49-9bfe-5f26df6b7458                                   0.0
#
# ProductID                             054ffafc-70c4-403f-adc8-18b59036a730  \
# UserID
# 0008ed95-9c61-4158-8e52-42cd0ca8d91a                                   0.0
# 00138209-0337-4d01-939a-8f96ec0a3e01                                   0.0
# 001391f8-8ccf-4ab5-ad79-2fdc6f47d715                                   0.0
# 0013b292-8412-4fef-b569-bfa2309c930c                                   0.0
# 001a2502-a12e-4f49-9bfe-5f26df6b7458                                   0.0
#
# ProductID                             055e3f74-5f78-42a4-b8a3-0f209914eb0b  \
# UserID
# 0008ed95-9c61-4158-8e52-42cd0ca8d91a                                   0.0
# 00138209-0337-4d01-939a-8f96ec0a3e01                                   0.0
# 001391f8-8ccf-4ab5-ad79-2fdc6f47d715                                   0.0
# 0013b292-8412-4fef-b569-bfa2309c930c                                   0.0
# 001a2502-a12e-4f49-9bfe-5f26df6b7458                                   0.0
#
# ProductID                             059459d8-da54-4d5c-b648-a4ce53b20b81  \
# UserID
# 0008ed95-9c61-4158-8e52-42cd0ca8d91a                             217.38154
# 00138209-0337-4d01-939a-8f96ec0a3e01                               0.00000
# 001391f8-8ccf-4ab5-ad79-2fdc6f47d715                               0.00000
# 0013b292-8412-4fef-b569-bfa2309c930c                               0.00000
# 001a2502-a12e-4f49-9bfe-5f26df6b7458                               0.00000
#
# ProductID                             ...  \
# UserID                                ...
# 0008ed95-9c61-4158-8e52-42cd0ca8d91a  ...
# 00138209-0337-4d01-939a-8f96ec0a3e01  ...
# 001391f8-8ccf-4ab5-ad79-2fdc6f47d715  ...
# 0013b292-8412-4fef-b569-bfa2309c930c  ...
# 001a2502-a12e-4f49-9bfe-5f26df6b7458  ...
#
# ProductID                             f7e5b495-99f3-4979-9005-ae6203ea9852  \
# UserID
# 0008ed95-9c61-4158-8e52-42cd0ca8d91a                                   0.0
# 00138209-0337-4d01-939a-8f96ec0a3e01                                   0.0
# 001391f8-8ccf-4ab5-ad79-2fdc6f47d715                                   0.0
# 0013b292-8412-4fef-b569-bfa2309c930c                                   0.0
# 001a2502-a12e-4f49-9bfe-5f26df6b7458                                   0.0
#
# ProductID                             f9b9dae9-56cc-4af2-ab7f-bf3002361d77  \
# UserID
# 0008ed95-9c61-4158-8e52-42cd0ca8d91a                                   0.0
# 00138209-0337-4d01-939a-8f96ec0a3e01                                   0.0
# 001391f8-8ccf-4ab5-ad79-2fdc6f47d715                                   0.0
# 0013b292-8412-4fef-b569-bfa2309c930c                                   0.0
# 001a2502-a12e-4f49-9bfe-5f26df6b7458                                   0.0
#
# ProductID                             faac44d2-596c-46cb-84e7-c8091b44ce66  \
# UserID
# 0008ed95-9c61-4158-8e52-42cd0ca8d91a                                   0.0
# 00138209-0337-4d01-939a-8f96ec0a3e01                                   0.0
# 001391f8-8ccf-4ab5-ad79-2fdc6f47d715                                   0.0
# 0013b292-8412-4fef-b569-bfa2309c930c                                   0.0
# 001a2502-a12e-4f49-9bfe-5f26df6b7458                                   0.0
#
# ProductID                             fc925b43-e836-4810-b23d-f70fb8b4a170  \
# UserID
# 0008ed95-9c61-4158-8e52-42cd0ca8d91a                                   0.0
# 00138209-0337-4d01-939a-8f96ec0a3e01                                   0.0
# 001391f8-8ccf-4ab5-ad79-2fdc6f47d715                                   0.0
# 0013b292-8412-4fef-b569-bfa2309c930c                                   0.0
# 001a2502-a12e-4f49-9bfe-5f26df6b7458                                   0.0
#
# ProductID                             fd7f2c4c-6136-46b9-8679-34dc3e776312  \
# UserID
# 0008ed95-9c61-4158-8e52-42cd0ca8d91a                                   0.0
# 00138209-0337-4d01-939a-8f96ec0a3e01                                   0.0
# 001391f8-8ccf-4ab5-ad79-2fdc6f47d715                                   0.0
# 0013b292-8412-4fef-b569-bfa2309c930c                                   0.0
# 001a2502-a12e-4f49-9bfe-5f26df6b7458                                   0.0
#
# ProductID                             fdc76976-2492-471e-a86b-c23c8c8d4e17  \
# UserID
# 0008ed95-9c61-4158-8e52-42cd0ca8d91a                                   0.0
# 00138209-0337-4d01-939a-8f96ec0a3e01                                   0.0
# 001391f8-8ccf-4ab5-ad79-2fdc6f47d715                                   0.0
# 0013b292-8412-4fef-b569-bfa2309c930c                                   0.0
# 001a2502-a12e-4f49-9bfe-5f26df6b7458                                   0.0
#
# ProductID                             fe5516e7-1bbd-465c-ab33-04f3b0d0eff8  \
# UserID
# 0008ed95-9c61-4158-8e52-42cd0ca8d91a                                   0.0
# 00138209-0337-4d01-939a-8f96ec0a3e01                                   0.0
# 001391f8-8ccf-4ab5-ad79-2fdc6f47d715                                   0.0
# 0013b292-8412-4fef-b569-bfa2309c930c                                   0.0
# 001a2502-a12e-4f49-9bfe-5f26df6b7458                                   0.0
#
# ProductID                             fef54a5c-4339-40f0-b067-4a5a828ec07f  \
# UserID
# 0008ed95-9c61-4158-8e52-42cd0ca8d91a                                   0.0
# 00138209-0337-4d01-939a-8f96ec0a3e01                                   0.0
# 001391f8-8ccf-4ab5-ad79-2fdc6f47d715                                   0.0
# 0013b292-8412-4fef-b569-bfa2309c930c                                   0.0
# 001a2502-a12e-4f49-9bfe-5f26df6b7458                                   0.0
#
# ProductID                             ff4cd37d-0006-43ec-9fee-fa86eba868bc  \
# UserID
# 0008ed95-9c61-4158-8e52-42cd0ca8d91a                                   0.0
# 00138209-0337-4d01-939a-8f96ec0a3e01                                   0.0
# 001391f8-8ccf-4ab5-ad79-2fdc6f47d715                                   0.0
# 0013b292-8412-4fef-b569-bfa2309c930c                                   0.0
# 001a2502-a12e-4f49-9bfe-5f26df6b7458                                   0.0
#
# ProductID                             ff8fd7ab-b101-4637-8e7b-92513fc68335
# UserID
# 0008ed95-9c61-4158-8e52-42cd0ca8d91a                                   0.0
# 00138209-0337-4d01-939a-8f96ec0a3e01                                   0.0
# 001391f8-8ccf-4ab5-ad79-2fdc6f47d715                                   0.0
# 0013b292-8412-4fef-b569-bfa2309c930c                                   0.0
# 001a2502-a12e-4f49-9bfe-5f26df6b7458                                   0.0
#
# [5 rows x 350 columns]

# %% [markdown]
# 1.3 User-Based Collaborative Filtering

# %%
# Compute User Similarity Matrix
user_similarity = cosine_similarity(interaction_matrix)
user_similarity_df = pd.DataFrame(user_similarity, index=interaction_matrix.index, columns=interaction_matrix.index)

# Recommend Products
def user_based_cf_recommendations(user_id, top_n=31):
    similar_users = user_similarity_df[user_id].sort_values(ascending=False)[1:top_n+1]
    similar_user_ids = similar_users.index

    # Get products interacted by similar users
    recommendations = interaction_matrix.loc[similar_user_ids].sum(axis=0)
    recommendations = recommendations[recommendations > 0].sort_values(ascending=False)
    return recommendations.index[:top_n].tolist()

# Example: Recommend for a specific user
print(user_based_cf_recommendations("0008ed95-9c61-4158-8e52-42cd0ca8d91a"))
# Out:
# ['059459d8-da54-4d5c-b648-a4ce53b20b81', '57c16c01-01a5-4b79-acaa-766ae3c6a8e1', '8b7a93ff-9f51-412f-b450-188c840f9840', 'da022965-c519-4b30-b0ba-5add5d232648', 'd8d3a080-7dfd-4df2-b31d-0c1fb95d937a', 'f0f60f98-0f6f-4989-b387-257870519e65', 'a049c7ed-460c-4e83-96a4-4144fa4f105f', 'e3d2e044-15ef-4c75-b3e0-39fd5965962d', '19f50ba0-c617-4e33-a10c-82a9871a5547', 'ddecb8b8-2e73-4b9f-8cc7-969a109b18a2', '133761fd-b760-4983-9fdc-e072776ffa2e']

# %%
# Function to fetch product details for a list of ProductIDs
def fetch_product_details(product_ids):
    # Filter the product_data DataFrame to get details for the given products
    return product_data[product_data['ProductID'].isin(product_ids)][
        ['ProductID', 'ProductName', 'Category', 'BasePrice', 'Description']
    ]

# %%
# Example: Recommend for a specific user and fetch product details
user_id = "0008ed95-9c61-4158-8e52-42cd0ca8d91a"
recommended_products = user_based_cf_recommendations(user_id)
product_details = fetch_product_details(recommended_products)
product_details
# Out:
#                                 ProductID  \
# 39   da022965-c519-4b30-b0ba-5add5d232648
# 59   e3d2e044-15ef-4c75-b3e0-39fd5965962d
# 82   059459d8-da54-4d5c-b648-a4ce53b20b81
# 88   133761fd-b760-4983-9fdc-e072776ffa2e
# 93   f0f60f98-0f6f-4989-b387-257870519e65
# 121  d8d3a080-7dfd-4df2-b31d-0c1fb95d937a
# 138  a049c7ed-460c-4e83-96a4-4144fa4f105f
# 160  19f50ba0-c617-4e33-a10c-82a9871a5547
# 287  ddecb8b8-2e73-4b9f-8cc7-969a109b18a2
# 296  57c16c01-01a5-4b79-acaa-766ae3c6a8e1
#
#                                     ProductName  Category  BasePrice  \
# 39                 User-friendly exuding policy         0   0.826468
# 59            Organized well-modulated forecast         0   0.451917
# 82                     Cloned maximized adapter         2   0.138056
# 88   Re-contextualized hybrid Internet solution         4   0.304099
# 93                 Customizable modular project         3   0.278911
# 121         Right-sized 5thgeneration challenge         1   0.077272
# 138             Future-proofed national synergy         6   0.228837
# 160            Polarized neutral conglomeration         2   0.105505
# 287              Assimilated maximized paradigm         6   0.304099
# 296      Open-architected leadingedge hierarchy         2   0.366045
#
#                                            Description
# 39   Point no shoulder whatever phone head organiza...
# 59   Sound economy interest draw wonder board call ...
# 82   Able water impact listen friend computer give ...
# 88   Rock somebody agree arm my most listen happen ...
# 93   Model price with may this break day describe b...
# 121  Skin oil event left garden factor business pol...
# 138   Approach water financial occur cut say yourself.
# 160     Because upon nor region mind whom door person.
# 287  Water opportunity challenge so recognize becom...
# 296  Daughter Republican other sea live similar eit...

# %% [markdown]
# 1.4 Item-Based Collaborative Filtering

# %%
# Compute Item Similarity Matrix
item_similarity = cosine_similarity(interaction_matrix.T)
item_similarity_df = pd.DataFrame(item_similarity, index=interaction_matrix.columns, columns=interaction_matrix.columns)

# Recommend Similar Products
def item_based_cf_recommendations(product_id, top_n=5):
    similar_items = item_similarity_df[product_id].sort_values(ascending=False)[1:top_n+1]
    return similar_items.index.tolist()

# Example: Recommend similar products to a specific product
print(item_based_cf_recommendations("026371c3-35b4-470a-899a-64baf6d6e1c3"))
# Out:
# ['88114487-ee4d-42de-ad55-83af1e286a97', '7843a4ce-d40e-42f2-b42d-e6d003e7da9d', 'ceff7040-7f67-4172-aadf-e61ec7b0474e', '9504bd90-19ef-4a89-800e-0e9a04cbcc31', 'b8608ba0-daff-4863-9ced-65cc5658949a']

# %%
prduct_id = "026371c3-35b4-470a-899a-64baf6d6e1c3"
recommended_products = item_based_cf_recommendations(product_id)
product_details = fetch_product_details(recommended_products)
product_details
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 2
#       1 prduct_id = "026371c3-35b4-470a-899a-64baf6d6e1c3"
# ----> 2 recommended_products = item_based_cf_recommendations(product_id)
#       3 product_details = fetch_product_details(recommended_products)
#       4 product_details
#
# NameError: name 'product_id' is not defined

# %% [markdown]
# ## 2. Content-Based Filtering on Product Features
# 2.1 Compute Product Similarity

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import StandardScaler

# Combine numeric and textual features
vectorizer = TfidfVectorizer(max_features=100)
product_description_vectors = vectorizer.fit_transform(product_data['Description'])

scaler = StandardScaler()
product_numeric_features = scaler.fit_transform(product_data[['BasePrice', 'StockQuantity', 'DiscountAmount']])

# Concatenate features
from scipy.sparse import hstack
product_features = hstack([product_description_vectors, product_numeric_features])

# Compute Product Similarity
product_similarity = cosine_similarity(product_features)
product_similarity_df = pd.DataFrame(product_similarity, index=product_data['ProductID'], columns=product_data['ProductID'])

# %% [markdown]
# #### 2.2 Recommend Products Based on Similarity

# %%
def content_based_recommendations(product_id, top_n=5):
    similar_products = product_similarity_df[product_id].sort_values(ascending=False)[1:top_n+1]
    return similar_products.index.tolist()

# Example: Recommend for a specific product
print(content_based_recommendations("026371c3-35b4-470a-899a-64baf6d6e1c3"))
# Out:
# ['d8ff3e79-e446-472a-9c54-88fe0b2f4dcd', '79525bf9-5585-41fe-aeac-391c89aa8a76', '779c3fb1-8b9e-4f17-b0a5-12ad416979c6', '54e001b1-0f23-4237-ba4a-5f4166b01d84', '7272509e-ba2a-453d-bdd2-ca4ad3fbb1fc']

# %%
product_id = "026371c3-35b4-470a-899a-64baf6d6e1c3"
recommended_products = content_based_recommendations(product_id)
product_details = fetch_product_details(recommended_products)
product_details
# Out:
#                                 ProductID  \
# 35   7272509e-ba2a-453d-bdd2-ca4ad3fbb1fc
# 76   79525bf9-5585-41fe-aeac-391c89aa8a76
# 166  d8ff3e79-e446-472a-9c54-88fe0b2f4dcd
# 202  54e001b1-0f23-4237-ba4a-5f4166b01d84
# 209  779c3fb1-8b9e-4f17-b0a5-12ad416979c6
#
#                                     ProductName  Category  BasePrice  \
# 35            Customer-focused global benchmark         4   0.123176
# 76   Enterprise-wide 5thgeneration installation         3   0.214842
# 166       Re-contextualized full-range attitude         4   0.136241
# 202                   Intuitive mobile hardware         1   0.128141
# 209           Multi-lateral interactive archive         3   0.088576
#
#                                            Description
# 35   Suddenly build discussion down mention piece c...
# 76   Room fire leader treat why environment their p...
# 166        Beyond test again realize play race effect.
# 202  Turn member however star garden current field ...
# 209       Pick serve always total attack tonight seek.

# %% [markdown]
# ## 3. Matrix Factorization and Clustering on User Data
# 3.1 Clustering Users

# %%
from sklearn.cluster import KMeans

# Features for clustering
clustering_features = user_data[['Gender', 'Age', 'TotalSpent', 'TotalTransactions']].fillna(0)

# Fit KMeans model
kmeans = KMeans(n_clusters=5, random_state=42)
user_data['Cluster'] = kmeans.fit_predict(clustering_features)

# Recommend products based on cluster preferences
def cluster_based_recommendations(user_id, top_n=5):
    user_cluster = user_data.loc[user_data['UserID'] == user_id, 'Cluster'].values[0]
    cluster_users = user_data[user_data['Cluster'] == user_cluster]['UserID']
    cluster_transactions = transaction_data[transaction_data['UserID'].isin(cluster_users)]
    
    # Get most purchased products in the cluster
    recommendations = cluster_transactions['ProductID'].value_counts().head(top_n).index.tolist()
    return recommendations

# %%
# Example: Recommend for a specific user and fetch product details
user_id = "0008ed95-9c61-4158-8e52-42cd0ca8d91a"
recommended_products = cluster_based_recommendations(user_id)
product_details = fetch_product_details(recommended_products)
product_details
# Out:
#                                 ProductID  \
# 89   b505a64f-511f-4e52-8f8f-6b0e70413582
# 191  81277098-4ea8-4809-a9ae-08875715ab62
# 224  30bd19fd-a2d5-4df5-838e-16a5f6733844
# 249  30a8e727-c7ce-43ef-abe1-e8ee2a5cd404
# 270  b71e297b-a2c3-4923-90a8-91135e3fa60b
#
#                                   ProductName  Category  BasePrice  \
# 89                    Phased dynamic alliance         0   0.331273
# 191                Progressive dynamic policy         2   0.267437
# 224               Streamlined radical toolset         2   0.270138
# 249  Enterprise-wide 3rdgeneration monitoring         2   0.341525
# 270               Advanced empowering project         2   0.205809
#
#                                            Description
# 89   About never value where home lay land son bed ...
# 191  Performance head true black wife author networ...
# 224         High part most world stay that bill point.
# 249  Number find perhaps last hour industry increas...
# 270  Would occur week expect front himself score re...

# %% [markdown]
# ## 4. Combine Recommendations
# We’ll combine recommendations by weighting each dataset-specific recommendation strategy.

# %%
def combine_recommendations(user_id, product_id=None, weights=[0.4,0.3, 0.2, 0.1], top_n=5):
    # Get recommendations from different models
    user_cf = user_based_cf_recommendations(user_id, top_n)
    item_cf = item_based_cf_recommendations(product_id, top_n) if product_id else []
    content_recs = content_based_recommendations(product_id, top_n) if product_id else []
    cluster_recs = cluster_based_recommendations(user_id, top_n)
    
    # Create a dictionary to aggregate recommendations with scores
    recommendation_scores = {}

    # Helper function to update scores
    def add_scores(recs, weight):
        for product_id in recs:  # If recs are simple product IDs
            if product_id in recommendation_scores:
                recommendation_scores[product_id] += weight
            else:
                recommendation_scores[product_id] = weight

    # Update scores from different recommendation sources
    add_scores(user_cf, weights[0])
    add_scores(item_cf, weights[1])
    add_scores(content_recs, weights[2])
    add_scores(cluster_recs, weights[3])

    # Sort recommendations by score in descending order
    sorted_recommendations = sorted(recommendation_scores.items(), key=lambda x: x[1], reverse=True)

    # Return the top N recommendations
    return [product for product, score in sorted_recommendations[:top_n]]

# Example: Final Recommendations
print(combine_recommendations("0008ed95-9c61-4158-8e52-42cd0ca8d91a", product_id="026371c3-35b4-470a-899a-64baf6d6e1c3"))
# Out:
# ['059459d8-da54-4d5c-b648-a4ce53b20b81', '88114487-ee4d-42de-ad55-83af1e286a97', '7843a4ce-d40e-42f2-b42d-e6d003e7da9d', 'ceff7040-7f67-4172-aadf-e61ec7b0474e', '9504bd90-19ef-4a89-800e-0e9a04cbcc31']

# %%
# Function to fetch product details for the recommended products
def fetch_product_details(recommended_products):
    # Filter the product_data DataFrame to get details for the recommended products
    product_details = product_data[product_data['ProductID'].isin(recommended_products)]
    return product_details[['ProductID', 'ProductName', 'Category', 'BasePrice', 'Description']]

# Example Usage
# Get combined recommendations
recommended_products = combine_recommendations(
    user_id="0008ed95-9c61-4158-8e52-42cd0ca8d91a",
    product_id="026371c3-35b4-470a-899a-64baf6d6e1c3",
    weights=[0.4, 0.3, 0.2, 0.1],
    top_n=5
)

# Fetch product details for the recommended products
product_details_df = fetch_product_details(recommended_products)

# Display the recommended product details
product_details_df
# Out:
#                                 ProductID  \
# 82   059459d8-da54-4d5c-b648-a4ce53b20b81
# 164  ceff7040-7f67-4172-aadf-e61ec7b0474e
# 183  9504bd90-19ef-4a89-800e-0e9a04cbcc31
# 238  88114487-ee4d-42de-ad55-83af1e286a97
# 275  7843a4ce-d40e-42f2-b42d-e6d003e7da9d
#
#                                ProductName  Category  BasePrice  \
# 82                Cloned maximized adapter         2   0.138056
# 164          Optimized holistic monitoring         6   1.000000
# 183  Fundamental fault-tolerant monitoring         4   0.107484
# 238              Devolved didactic project         1   0.066982
# 275        Secured asynchronous complexity         4   0.304099
#
#                                            Description
# 82   Able water impact listen friend computer give ...
# 164  Consumer factor expect either human certain lo...
# 183  Necessary chance international of local standa...
# 238  Professor investment fast goal find condition ...
# 275       Room both little million sport Mrs language.

# %% [markdown]
# ## 2. Ranking Aggregation
# Here, we combine rankings from different models. Each model assigns ranks, and we aggregate them using methods like Borda Count or Reciprocal Rank Fusion (RRF).

# %%
def rank_aggregation_hybrid_recommendations(user_id, product_id=None, k=60, top_n=5):
    # Get recommendations from different models
    user_cf = user_based_cf_recommendations(user_id, k)
    item_cf = item_based_cf_recommendations(product_id, k) if product_id else []
    cluster_recs = cluster_based_recommendations(user_id, k)

    # Combine rankings using RRF
    ranking_scores = {}
    models = [user_cf, item_cf, cluster_recs]
    for model in models:
        for rank, product_id in enumerate(model):
            if product_id in ranking_scores:
                ranking_scores[product_id] += 1 / (rank + 1)
            else:
                ranking_scores[product_id] = 1 / (rank + 1)

    # Sort and return top recommendations
    sorted_recommendations = sorted(ranking_scores.items(), key=lambda x: x[1], reverse=True)
    return [product for product, score in sorted_recommendations[:top_n]]

# %%
# Example: User and Product Details
user_id = "0008ed95-9c61-4158-8e52-42cd0ca8d91a"
product_id = "026371c3-35b4-470a-899a-64baf6d6e1c3"

# Display given product details
given_product_details = fetch_product_details([product_id])
print("Given Product Details:")
print(given_product_details)

# Get recommendations from the hybrid rank aggregation model
recommended_products = rank_aggregation_hybrid_recommendations(user_id, product_id, k=60, top_n=5)

# Display details of recommended products
recommended_product_details = fetch_product_details(recommended_products)
print("\nRecommended Products:")
recommended_product_details
# Out:
# Given Product Details:
#                                ProductID                          ProductName  \
# 92  026371c3-35b4-470a-899a-64baf6d6e1c3  Down-sized maximized infrastructure
#
#     Category  BasePrice                                        Description
# 92         5   0.130266  Huge daughter present north light part yeah te...
#
# Recommended Products:
#                                 ProductID                      ProductName  \
# 82   059459d8-da54-4d5c-b648-a4ce53b20b81         Cloned maximized adapter
# 191  81277098-4ea8-4809-a9ae-08875715ab62       Progressive dynamic policy
# 202  54e001b1-0f23-4237-ba4a-5f4166b01d84        Intuitive mobile hardware
# 238  88114487-ee4d-42de-ad55-83af1e286a97        Devolved didactic project
# 275  7843a4ce-d40e-42f2-b42d-e6d003e7da9d  Secured asynchronous complexity
#
#      Category  BasePrice                                        Description
# 82          2   0.138056  Able water impact listen friend computer give ...
# 191         2   0.267437  Performance head true black wife author networ...
# 202         1   0.128141  Turn member however star garden current field ...
# 238         1   0.066982  Professor investment fast goal find condition ...
# 275         4   0.304099       Room both little million sport Mrs language.

# %%
from sklearn.model_selection import train_test_split

train_data, test_data = train_test_split(interaction_Data, test_size=0.3, random_state=42)
val_data, test_data = train_test_split(test_data, test_size=0.5, random_state=42)

# %%
test_data.head()
# Out:
#                               InteractionID  \
# 19363  9e13e3a5-18bf-468b-9e87-c66cfbdda3e5
# 18425  5b730ae2-089d-4b87-983d-371c8af53b03
# 2226   504cd79f-bafe-45e1-879b-eff31f87a083
# 24724  9818a81c-0f28-4623-b273-2c60078b3ba9
# 8277   2b77ed94-7f4d-41d7-af60-79d3e92e5cb8
#
#                                      UserID  \
# 19363  1798d08b-2f1a-43ba-815b-e5b36d23729b
# 18425  19dbebbd-4b63-4bf8-8020-b80d7302f695
# 2226   475547b6-f9b5-48f2-a718-4c5b6c1bdcf6
# 24724  e2a85afd-6767-4c16-8f4c-86f47e497869
# 8277   0b347277-958b-4099-afae-c798412240c3
#
#                                   ProductID  ViewedPages  ProductViewHistory  \
# 19363  222f94fb-14c8-40d4-8356-ff0e9fe538ee     0.263158                  26
# 18425  165492b9-16bf-4023-8d30-dd7beff58269     0.631579                  29
# 2226   f52a0fe3-293d-42b0-8cae-06823b6d7dcb     1.000000                  18
# 24724  208d70ba-a7f4-4ecb-ba9a-c5bdd369145b     0.631579                  53
# 8277   b366e7e8-36eb-461c-b49a-c3536935045b     1.000000                  80
#
#        SearchQueries  TimeSpentOnPages  WishlistItems  CartAddedItems  \
# 19363             16          0.123786              8               1
# 18425             14          0.210691              6               2
# 2226              17          0.139864              4               9
# 24724              3          0.115785              8               2
# 8277              20          0.010763              7               7
#
#        CartAbandonedItems  ReviewRating  \
# 19363                   7      3.000000
# 18425                   7      3.006931
# 2226                    7      3.000000
# 24724                   9      5.000000
# 8277                    0      1.000000
#
#                                               ReviewText  CompositeScore
# 19363  Truth success center thought music us wrong st...      132.510730
# 18425  Avoid whatever these color clear finally servi...      130.073755
# 2226   Be experience case let develop minute like roa...      144.279728
# 24724  Give organization land week more compare deep ...      154.863149
# 8277                                  No review provided      287.021526

# %%
import numpy as np
from sklearn.metrics import precision_score, recall_score, f1_score, mean_squared_error

# Evaluation Metrics Functions

def calculate_precision_recall_f1(true_products, recommended_products):
    """
    Calculate Precision, Recall, and F1-Score for recommendations.
    """
    y_true = [1 if product in true_products else 0 for product in recommended_products]
    y_pred = [1] * len(recommended_products)  # Recommended products are considered positive.
    
    precision = precision_score(y_true, y_pred, zero_division=0)
    recall = recall_score(y_true, y_pred, zero_division=0)
    f1 = f1_score(y_true, y_pred, zero_division=0)
    
    return precision, recall, f1


def mean_average_precision(true_products, recommended_products):
    """
    Compute Mean Average Precision (MAP).
    """
    hits = 0
    avg_precision = 0.0
    for i, product in enumerate(recommended_products):
        if product in true_products:
            hits += 1
            avg_precision += hits / (i + 1)
    return avg_precision / len(true_products) if true_products else 0


def mean_reciprocal_rank(true_products, recommended_products):
    """
    Compute Mean Reciprocal Rank (MRR).
    """
    for i, product in enumerate(recommended_products):
        if product in true_products:
            return 1 / (i + 1)
    return 0


# Evaluation Function
def evaluate_recommendations(test_data, top_n=5):
    """
    Evaluate the `rank_aggregation_hybrid_recommendations` function.
    :param test_data: DataFrame with 'UserID' and 'ProductID' columns.
    :param top_n: Number of recommendations to generate for each user.
    :return: Dictionary of evaluation metrics.
    """
    precision_list, recall_list, f1_list = [], [], []
    map_list, mrr_list = [], []

    # Iterate through unique users in the test set
    for user_id in test_data['UserID'].unique():
        # True products for the user
        true_products = test_data[test_data['UserID'] == user_id]['ProductID'].tolist()

        # Get recommended products from the hybrid function
        recommended_products = rank_aggregation_hybrid_recommendations(user_id, top_n=top_n)

        # Compute metrics
        precision, recall, f1 = calculate_precision_recall_f1(true_products, recommended_products)
        map_score = mean_average_precision(true_products, recommended_products)
        mrr_score = mean_reciprocal_rank(true_products, recommended_products)

        # Append scores
        precision_list.append(precision)
        recall_list.append(recall)
        f1_list.append(f1)
        map_list.append(map_score)
        mrr_list.append(mrr_score)

    # Aggregate results
    return {
        "Precision": np.mean(precision_list),
        "Recall": np.mean(recall_list),
        "F1-Score": np.mean(f1_list),
        "MAP": np.mean(map_list),
        "MRR": np.mean(mrr_list)
    }


# Example Usage
# Assuming `test_data` is a DataFrame with 'UserID' and 'ProductID'
results = evaluate_recommendations(test_data, top_n=5)

# Print the evaluation results
print("Evaluation Metrics:")
for metric, value in results.items():
    print(f"{metric}: {value:.4f}")
# Out:
# Evaluation Metrics:
# Precision: 0.1802
# Recall: 0.8682
# F1-Score: 0.2972
# MAP: 0.7012
# MRR: 0.7225

# %%
def evaluate_combine_recommendations(test_data, top_n=5):
    """
    Evaluate the `combine_recommendations` function.
    :param test_data: DataFrame with 'UserID' and 'ProductID' columns.
    :param top_n: Number of recommendations to generate for each user.
    :return: Dictionary of evaluation metrics.
    """
    precision_list, recall_list, f1_list = [], [], []

    # Iterate through unique users in the test set
    for user_id in test_data['UserID'].unique():
        # True products for the user
        true_products = test_data[test_data['UserID'] == user_id]['ProductID'].tolist()

        # Get recommended products from the combine function
        recommended_products = combine_recommendations(user_id, top_n=top_n)

        # Compute metrics
        precision, recall, f1 = calculate_precision_recall_f1(true_products, recommended_products)

        # Append scores
        precision_list.append(precision)
        recall_list.append(recall)
        f1_list.append(f1)

    # Aggregate results
    return {
        "Precision": np.mean(precision_list),
        "Recall": np.mean(recall_list),
        "F1-Score": np.mean(f1_list),
    }

# Example Usage
# Assuming `test_data` is a DataFrame with 'UserID' and 'ProductID'
results = evaluate_combine_recommendations(test_data, top_n=5)

# Print the evaluation results
print("Evaluation Metrics for combine_recommendations:")
for metric, value in results.items():
    print(f"{metric}: {value:.4f}")
# Out:
# Evaluation Metrics for combine_recommendations:
# Precision: 0.1492
# Recall: 0.7370
# F1-Score: 0.2479
